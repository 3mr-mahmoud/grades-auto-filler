# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from final import *
import os
from PIL import Image
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

# imgs_path = 'samples/2'
# answer_path = 'samples/2/answers.txt'

# # Get list of all jpg images and sort numerically
# img_files = [f for f in os.listdir(imgs_path) if f.lower().endswith('.jpg')]
# img_files.sort(key=lambda x: int(x.split('.')[0]))  # Sort based on the number before the extension

# for img_path in img_files:
#     # Read image
#     print('Processing image:', os.path.join(imgs_path, img_path))
#     process_bubble_sheet(os.path.join(imgs_path, img_path), answer_path)

image_path = '../../Dataset/Bubble Sheet/4/8.jpg'
answer_path = '../../Dataset/Bubble Sheet/4/answers.txt'
process_bubble_sheet(image_path, answer_path)
# Out:
# Image shape: (4032, 3024, 3)
# Extracted image shape: (3229, 2645, 3)
# Number of contours found: 3208
# Dimensions of contours: [(343, 1118, 510, 1765), (413, 371, 981, 618), (1110, 1120, 418, 1764), (1802, 1113, 424, 1772)]
# Detected grid size: 7 rows x 10 columns
# Original circles: 68
# Total circles after completion: 70
# Detected grid size: 15 rows x 4 columns
# Original circles: 60
# Total circles after completion: 60
# Detected grid size: 15 rows x 4 columns
# Original circles: 60
# Total circles after completion: 60
# Detected grid size: 15 rows x 4 columns
# Original circles: 60
# Total circles after completion: 60
# cols 4
# ID:  1111111
# Question 1: ['A']
# Question 2: ['B']
# Question 3: ['C']
# Question 4: ['D']
# Question 5: ['C']
# Question 6: ['']
# Question 7: ['A']
# Question 8: ['']
# Question 9: ['']
# Question 10: ['']
# Question 11: ['C']
# Question 12: ['']
# Question 13: ['C']
# Question 14: ['B']
# Question 15: ['']
# Question 16: ['']
# Question 17: ['B']
# Question 18: ['']
# Question 19: ['B']
# Question 20: ['A']
# Question 21: ['B']
# Question 22: ['C']
# Question 23: ['D']
# Question 24: ['C']
# Question 25: ['']
# Question 26: ['C']
# Question 27: ['']
# Question 28: ['B']
# Question 29: ['']
# Question 30: ['B']
# Question 31: ['A']
# Question 32: ['B']
# Question 33: ['C']
# Question 34: ['B']
# Question 35: ['A']
# Question 36: ['']
# Question 37: ['B']
# Question 38: ['B']
# Question 39: ['B']
# Question 40: ['C']
# Question 41: ['C']
# Question 42: ['B']
# Question 43: ['B']
# Question 44: ['']
# Question 45: ['']
# Final Answers: [['A'], ['B'], ['C'], ['D'], ['C'], [''], ['A'], [''], [''], [''], ['C'], [''], ['C'], ['B'], [''], [''], ['B'], [''], ['B'], ['A'], ['B'], ['C'], ['D'], ['C'], [''], ['C'], [''], ['B'], [''], ['B'], ['A'], ['B'], ['C'], ['B'], ['A'], [''], ['B'], ['B'], ['B'], ['C'], ['C'], ['B'], ['B'], [''], ['']]
